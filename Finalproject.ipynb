# %%
#importing and displaying dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Dataset.csv') 
df.head()
# Out:
#    Surname  CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0     2023        668.0  33.0     3.0       0.00            2.0          1
# 1     2024        627.0  33.0     1.0       0.00            2.0          1
# 2     1236        678.0  40.0    10.0       0.00            2.0          1
# 3     1362        581.0  34.0     2.0  148882.54            1.0          1
# 4      491        716.0  33.0     5.0       0.00            2.0          1
#
#    IsActiveMember  EstimatedSalary  Exited  ...  France  Germany  Spain  \
# 0               0        181449.97       0  ...       1        0      0
# 1               1         49503.50       0  ...       1        0      0
# 2               0        184866.69       0  ...       1        0      0
# 3               1         84560.88       0  ...       1        0      0
# 4               1         15068.83       0  ...       0        0      1
#
#    Female  Male  Mem__no__Products  Cred_Bal_Sal   Bal_sal  Tenure_Age  \
# ...

# %% [markdown]
# As shown in the dataset, this is a sample of bank customers and the objective is to predict whether thew will leave the bank. The target variable in this case is the column 'Exited' where 0 = False and 1 = True.
# Below will be some visualisation to better understand the dataset and build a hypothesis based on the findings.

# %%
# Boxplot and correlation matrix


cm = df.corr
cm()
# Out:
#                      Surname  CreditScore       Age    Tenure   Balance  \
# Surname             1.000000     0.009076 -0.019451 -0.003101 -0.126933
# CreditScore         0.009076     1.000000 -0.008876  0.000959  0.005578
# Age                -0.019451    -0.008876  1.000000 -0.010786  0.063279
# Tenure             -0.003101     0.000959 -0.010786  1.000000 -0.009638
# Balance            -0.126933     0.005578  0.063279 -0.009638  1.000000
# NumOfProducts       0.050633     0.011608 -0.097307  0.007708 -0.357265
# HasCrCard           0.010640    -0.002618 -0.012602  0.006415 -0.020308
# IsActiveMember      0.002856     0.015376  0.008956 -0.006874 -0.014131
# EstimatedSalary     0.037894    -0.000774 -0.006693  0.001451  0.004412
# Exited             -0.027023    -0.027252  0.336603 -0.019237  0.128391
# Surname_tfidf_0    -0.085026     0.000919  0.005329 -0.001263  0.051860
# Surname_tfidf_1    -0.061105    -0.008427 -0.000317 -0.003681 -0.019675
# ...
